# %%
import ipywidgets as widgets

# %%
widgets.IntSlider()
# Out:
# IntSlider(value=0)

# %%
w=widgets.IntSlider()

# %%
from IPython.display import display

# %%
display(w)
# Out:
# IntSlider(value=0)

# %%
display(w)
# Out:
# IntSlider(value=51)

# %%
w.close()

# %%
w=widgets.IntSlider() #reconnect the widgets
display(w)
# Out:
# IntSlider(value=0)

# %%
w.value
# Out:
# 20

# %%
w.value=60

# %%
w.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'continuous_update',
#  'description',
#  'description_tooltip',
#  'disabled',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'readout',
#  'readout_format',
#  'step',
#  'style',
#  'value']

# %%
w.max =500

# %%
a=widgets.FloatText()
b = widgets.FloatSlider()

# %%
display(a)
# Out:
# FloatText(value=0.0)

# %%
display(a,b)
